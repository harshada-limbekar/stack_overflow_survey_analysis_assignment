# %%
#import pandas
import pandas as pd

# %%
#download csv file from 
#https://drive.google.com/file/d/1mNePeYPIryqxkP0Y92ajiX7XD69dPV69/view?usp=sharing

# %%
#read dataset from Csv file
df=pd.read_csv("survey_results_public.csv")
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
#display  info about dataset
df.info
# Out:
# <bound method DataFrame.info of        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
#describe dataset
df.describe
# Out:
# <bound method NDFrame.describe of        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# 7               8                        I code primarily as a hobby      Yes
# 8               9                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 10             11                        I code primarily as a hobby      Yes
# ...

# %%
#display all columns
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
#Which  is most used  programming langauge (use LanguageWorkedWith column)
df["LanguageWorkedWith"].value_counts().idxmax()
# Out:
# 'HTML/CSS;JavaScript;PHP;SQL'

# %%
#Display how many work remotely on pie chart  [use WorkRemote column]
e=df[df.WorkRemote=="Less than once per month / Never"].shape[0]
f=df[df.WorkRemote=="A few days each month"].shape[0]
g=df[df.WorkRemote=="All or almost all the time (I'm full-time remote)"].shape[0]
h=[e,f,g]
l=["Less than once per month / Never","A few days each month","All or almost all the time (I'm full-time remote)"]
colors=["red","blue","green"]
plt.pie(h,labels=l,colors=colors,autopct="%.f%%")
plt.show()

# %%
#Display how many male and female programmers on pie chart  [use Gender column]
a=df[df.Gender=="Man"].shape[0]
b=df[df.Gender=="Woman"].shape[0]
c=["Male","Female"]
d=[a,b]
import matplotlib.pyplot as plt
colors=["red","gold"]
plt.pie(d,labels=c,colors=colors,autopct="%.f%%")
plt.show()

# %%
#which developer type is in demand [use DevType column]
df["DevType"].value_counts().idxmax()
# Out:
# 'Developer, full-stack'

# %%
#which is langauge programmer is going to learn in next year[Display top 3] (use LanguageDesireNextYear column)
df['LanguageDesireNextYear'].value_counts()[0:3].sort_values(ascending=False)
# Out:
# Python                            1236
# HTML/CSS;JavaScript                697
# HTML/CSS;JavaScript;TypeScript     648
# Name: LanguageDesireNextYear, dtype: int64

# %%
#from which country programmer take part in survey[Display top 3] (use Country column)
df['Country'].value_counts()[0:3].sort_values(ascending=False)
# Out:
# United States    20949
# India             9061
# Germany           5866
# Name: Country, dtype: int64
